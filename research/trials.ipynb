# %%
d = {"key": "value", "key1": "value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

d2 = {"key": "value", "key1": "value1"}
d2 = ConfigBox(d2)

# %%
d2.key, d2.key1
# Out:
# ('value', 'value1')

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
def get_product(x: int, y: int):
    return x*y

# %%
get_product(2, "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# It ensure the data type which is mentioned in defination
@ ensure_annotations
def get_product(x: int, y: int):
    return x*y

# %%
get_product(2, "3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 get_product(2, "3")
#
# File d:\ML PROJECTS\Chest-cancer-classification-MLflow-dvc\venv\Lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001DAEBE18EA0> does not match annotation type <class 'int'>

# %% [markdown]
# ## Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1D_ekTLlJm2SWYQ9J1Q5pGdhxVY5E_99X/view?usp=sharing"

# %%
file_id = url.split('/')[-2]
file_id
# Out:
# '1D_ekTLlJm2SWYQ9J1Q5pGdhxVY5E_99X'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1D_ekTLlJm2SWYQ9J1Q5pGdhxVY5E_99X
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1D_ekTLlJm2SWYQ9J1Q5pGdhxVY5E_99X&confirm=t&uuid=b618a1b8-0a26-4c2b-acd5-21dd97230049
# To: d:\ML PROJECTS\Chest-cancer-classification-MLflow-dvc\research\Chest-CT-Scan-data.zip
# 100%|██████████| 124M/124M [00:05<00:00, 22.3MB/s]
# 'Chest-CT-Scan-data.zip'

# %%
import mlflow
from urllib.parse import urlparse

# %%
mlflow.get_tracking_uri()
# Out:
# 'https://dagshub.com/yashveer_saini/Chest-cancer-classification-MLflow-dvc.mlflow'
